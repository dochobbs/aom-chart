# %% [markdown]
# # Foundation record inventory review
# September 8, 2026. Reproduces the 17-folder inventory and verifies exact evidence spans.
# Text identity is not independent API provenance. Token limits are screening flags, not clinical scores.
# No experiment runner is imported and no provider call is made. See FOUNDATION_RESULTS_REVIEW_2026-09-08.md.

# %%
from pathlib import Path
import runpy
root = Path('/Users/dochobbs/consult/random/bias')
runpy.run_path(str(root / 'docs/reviews/audit_foundation_records.py'), run_name='__main__')
# Out:
# {
#   "scope": "17 named folders reproducing the supplied audit; records may lack execution timestamps",
#   "stored_records": 1778,
#   "folders": 17,
#   "distinct_text_records": 1586,
#   "extra_master_or_component_copies": 192,
#   "distinct_text_records_is_not_a_verified_request_count": true,
#   "represented_answer_fields_after_text_deduplication": 2758,
#   "empty_answer_fields": [
#     {
#       "ref": "results/mitigation_4cases/mitigation_4cases_20260907T030903Z.json#results[34]",
#       "field": "t1_text"
#     }
#   ],
#   "recorded_nonempty_error_fields": 0,
#   "records_without_error_field": 636,
#   "answer_fields_without_stop_reason": 2758,
#   "answer_fields_without_output_tokens": 350,
#   "answer_fields_without_latency": 340,
#   "answer_fields_at_exactly_4000_tokens": 87,
#   "token_limit_screen_is_not_an_adjudicated_truncation_count": true,
#   "mean_chars_per_answer_field_including_empty": 3295.783538796229,
#   "minimum_nonempty_answer_chars": 481,
# ...
